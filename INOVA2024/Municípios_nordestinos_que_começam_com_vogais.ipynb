# %% [markdown]
# <a href="https://colab.research.google.com/github/maisa-guimaraes/P4/blob/main/INOVA2024/Munic%C3%ADpios_nordestinos_que_come%C3%A7am_com_vogais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.25.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import time
import requests
import matplotlib.pyplot as plt

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_das_unidades_federativas_da_Regi%C3%A3o_Nordeste_do_Brasil'

tabelas = pd.read_html(url) # pd.read_html(url) serve para ler tabelas html e convertê-las em dataframes.

print(f'Total de tabelas encontradas: {len(tabelas)}')
print(50*'-')
df = tabelas[0] # Para escolher a primeira tabela da página
print(df)
# Out:
# Total de tabelas encontradas: 3
# --------------------------------------------------
#    Bandeira               Estado Abreviação      Capital         Área  \
# 0       NaN              Alagoas         AL       Maceió   27.848,140
# 1       NaN                Bahia         BA     Salvador  564.733,177
# 2       NaN                Ceará         CE    Fortaleza  148.920,472
# 3       NaN             Maranhão         MA     São Luís  331.937,450
# 4       NaN              Paraíba         PB  João Pessoa   56.469,778
# 5       NaN           Pernambuco         PE       Recife   98.148,323
# 6       NaN                Piauí         PI     Teresina  251.577,738
# 7       NaN  Rio Grande do Norte         RN        Natal   52.811,047
# 8       NaN              Sergipe         SE      Aracaju   21.915,081
#
#   População(censo 2022) Densidade(2010) PIB 2015 (% total do país)  \
# 0                   [1]       112,33[1]         46.364.000 (0,77%)
# 1                   [2]        24,82[2]        245.025.000 (4.09%)
# 2                   [3]        56,76[3]        130.621.000 (2,18%)
# 3                   NaN        19,81[4]         78.475.000 (1,31%)
# 4                   [5]        66,70[5]         56.140.000 (0,94%)
# 5                   NaN        89,62[6]        156.955.000 (2,62%)
# 6                   [7]        12,40[7]         39.148.000 (0,65%)
# 7                   NaN        59,99[8]         57.250.000 (0,95%)
# 8                   [9]        94,36[9]         38.554.000 (0,64%)
#
#    PIB per capita 2017 (R$)    IDH Literacia (2016)  \
# 0                     65800  0.631            80,6%
# 1                     86200  0.631            80,6%
# 2                     82400  0.682            84,8%
# 3                     59700  0.639            83,3%
# 4                     92800  0.658            83,7%
# 5                     85200  0.673            87,2%
# 6                     75000  0.646            82,8%
# 7                     84500  0.684            85,3%
# 8                     83600  0.665            85,3%
#
#   Mortalidade infantil (2016)  Expectativa de vida (2016)
# 0                       19,5%                         716
# 1                       19,5%                         716
# 2                       14,4%                         738
# 3                       21,3%                         706
# 4                       16,1%                         732
# 5                       12,7%                         739
# 6                       19,1%                         711
# 7                       14,7%                         757
# 8                       16,2%                         727

# %%
siglas = df['Abreviação']
print(siglas)
# Out:
# 0    AL
# 1    BA
# 2    CE
# 3    MA
# 4    PB
# 5    PE
# 6    PI
# 7    RN
# 8    SE
# Name: Abreviação, dtype: object

# %%
cidades_ne_vogais = []
estados_cidades_ne_vogais = []

for UF in siglas:
    url = f'https://servicodados.ibge.gov.br/api/v1/localidades/estados/{UF}/municipios'
    response = requests.get(url)
    estados_municipios = response.json()
    for municipio in estados_municipios:
      if municipio['nome'][0] in ('aeiouAEIOU'): # nome refere-se ao nome do município, sendo assim especificado no JSON.
        cidades_ne_vogais.append(municipio['nome']) # Se iniciado por vogal o nome do município é adicionado à lista
        estados_cidades_ne_vogais.append(UF) # Se o nome do município for iniciado por vogal, adiciona-se mais um à contagem por estado.

print('O total de municípios da região nordeste que começam com vogais é',len(cidades_ne_vogais))

print('\n' + 100 * '-' + '\n')

df_municipios = pd.DataFrame({
    'Municipio': cidades_ne_vogais,
    'Estado': estados_cidades_ne_vogais
})

df_municipios = df_municipios.sort_values(by='Municipio').reset_index(drop=True)

with pd.option_context('display.max_rows', None,):
  df_municipios.index = df_municipios.index + 1
  print(df_municipios)
# Out:
# O total de municípios da região nordeste que começam com vogais é 333
#
# ----------------------------------------------------------------------------------------------------
#
#                    Municipio Estado
# 1                    Abaiara     CE
# 2                      Abaré     BA
# 3                     Abaíra     BA
# 4               Abreu e Lima     PE
# 5                  Acajutiba     BA
# 6                    Acarape     CE
# 7                     Acaraú     CE
# 8                      Acari     RN
# 9                      Acauã     PI
# 10                  Acopiara     CE
# 11                  Adustina     BA
# 12     Afogados da Ingazeira     PE
# 13            Afonso Bezerra     RN
# 14              Afonso Cunha     MA
# 15                   Afrânio     PE
# 16                 Agrestina     PE
# 17              Agricolândia     PI
# 18                    Aguiar     PB
# 19                   Aiquara     BA
# 20                    Aiuaba     CE
# 21             Alagoa Grande     PB
# 22               Alagoa Nova     PB
# 23                 Alagoinha     PE
# 24                 Alagoinha     PB
# 25        Alagoinha do Piauí     PI
# 26                Alagoinhas     BA
# 27                  Alcantil     PB
# 28                  Alcobaça     BA
# 29                 Alcântara     MA
# 30                Alcântaras     CE
# 31             Aldeias Altas     MA
# 32         Alegrete do Piauí     PI
# 33                Alexandria     RN
# 34       Algodão de Jandaíra     PB
# 35                  Alhandra     PB
# 36                   Aliança     PE
# 37                  Almadina     BA
# 38             Almino Afonso     RN
# 39      Altamira do Maranhão     MA
# 40                 Altaneira     CE
# 41                   Altinho     PE
# 42   Alto Alegre do Maranhão     MA
# 43    Alto Alegre do Pindaré     MA
# 44                Alto Longá     PI
# 45             Alto Parnaíba     MA
# 46                Alto Santo     CE
# 47         Alto do Rodrigues     RN
# 48                     Altos     PI
# 49      Alvorada do Gurguéia     PI
# 50         Amapá do Maranhão     MA
# 51                   Amaraji     PE
# 52                  Amarante     PI
# 53      Amarante do Maranhão     MA
# 54                  Amargosa     BA
# 55                  Amontada     CE
# 56                    Amparo     PB
# 57   Amparo do São Francisco     SE
# 58          Amélia Rodrigues     BA
# 59           América Dourada     BA
# 60                    Anadia     AL
# 61                     Anagé     BA
# 62                 Anajatuba     MA
# 63                  Anapurus     MA
# 64                   Andaraí     BA
# 65                 Andorinha     BA
# 66                   Angelim     PE
# 67                   Angical     BA
# 68          Angical do Piauí     PI
# 69                   Angicos     RN
# 70                   Anguera     BA
# 71                     Antas     BA
# 72         Antonina do Norte     CE
# 73           Antônio Almeida     PI
# 74           Antônio Cardoso     BA
# 75         Antônio Gonçalves     BA
# 76           Antônio Martins     RN
# 77           Anísio de Abreu     PI
# 78                 Aparecida     PB
# 79                Apicum-Açu     MA
# 80                     Apodi     RN
# 81                     Aporá     BA
# 82                  Apuarema     BA
# 83                  Apuiarés     CE
# 84                  Aquidabã     SE
# 85                   Aquiraz     CE
# 86                   Aracaju     SE
# 87                   Aracati     CE
# 88                   Aracatu     BA
# 89                     Araci     BA
# 90                 Aracoiaba     CE
# 91                  Araguanã     MA
# 92                  Araioses     MA
# 93                   Aramari     BA
# 94                     Arame     MA
# 95                 Arapiraca     AL
# 96                     Arara     PB
# 97                  Ararendá     CE
# 98                     Arari     MA
# 99                   Araripe     CE
# 100                Araripina     PE
# 101                  Araruna     PB
# 102                  Arataca     BA
# 103                  Aratuba     CE
# 104                 Aratuípe     BA
# 105                    Arauá     SE
# 106                  Araçagi     PB
# 107                Araçoiaba     PE
# 108                   Araçás     BA
# 109                Arcoverde     PE
# 110                    Areia     PB
# 111             Areia Branca     SE
# 112             Areia Branca     RN
# 113        Areia de Baraúnas     PB
# 114                   Areial     PB
# 115                 Arneiroz     CE
# 116                  Aroazes     PI
# 117                 Aroeiras     PB
# 118        Aroeiras do Itaim     PI
# 119                  Arraial     PI
# 120                     Arês     RN
# 121                   Assaré     CE
# 122                 Assunção     PB
# 123        Assunção do Piauí     PI
# 124                  Atalaia     AL
# 125            Aurelino Leal     BA
# 126                   Aurora     CE
# 127            Avelino Lopes     PI
# 128                    Axixá     MA
# 129               Açailândia     MA
# 130                      Açu     RN
# 131           Elesbão Veloso     PI
# 132           Eliseu Martins     PI
# 133           Elísio Medrado     BA
# 134                     Emas     PB
# 135                  Encanto     RN
# 136             Encruzilhada     BA
# 137               Entre Rios     BA
# 138                  Equador     RN
# 139                    Ereré     CE
# 140                   Escada     PE
# 141              Esperantina     PI
# 142         Esperantinópolis     MA
# 143                Esperança     PB
# 144                Esplanada     BA
# 145           Espírito Santo     RN
# 146                 Estreito     MA
# 147       Estrela de Alagoas     AL
# 148                 Estância     SE
# 149        Euclides da Cunha     BA
# 150                Eunápolis     BA
# 151                  Eusébio     CE
# 152                 Extremoz     RN
# 153                      Exu     PE
# 154                     Iati     PE
# 155                     Iaçu     BA
# 156                Ibaretama     CE
# 157               Ibateguara     AL
# 158                 Ibiapina     CE
# 159                   Ibiara     PB
# 160                Ibiassucê     BA
# 161                 Ibicaraí     BA
# 162                 Ibicoara     BA
# 163              Ibicuitinga     CE
# 164                   Ibicuí     BA
# 165                 Ibimirim     PE
# 166                  Ibipeba     BA
# 167               Ibipitanga     BA
# 168                 Ibiquera     BA
# 169                Ibirajuba     PE
# 170             Ibirapitanga     BA
# 171                 Ibirapuã     BA
# 172                Ibirataia     BA
# 173                 Ibitiara     BA
# 174                  Ibititá     BA
# 175                Ibotirama     BA
# 176                   Icapuí     CE
# 177                    Icatu     MA
# 178                     Ichu     BA
# 179                      Icó     CE
# 180            Ielmo Marinho     RN
# 181                    Igaci     AL
# 182                  Igaporã     BA
# 183                  Igaracy     PB
# 184           Igarapé Grande     MA
# 185          Igarapé do Meio     MA
# 186                 Igarassu     PE
# 187                Igrapiúna     BA
# 188              Igreja Nova     AL
# 189                 Iguaracy     PE
# 190                   Iguatu     CE
# 191                    Iguaí     BA
# 192              Ilha Grande     PI
# 193          Ilha das Flores     SE
# 194        Ilha de Itamaracá     PE
# 195                   Ilhéus     BA
# 196                Imaculada     PB
# 197               Imperatriz     MA
# 198                    Inajá     PE
# 199            Independência     CE
# 200                Indiaroba     SE
# 201                Ingazeira     PE
# 202                     Ingá     PB
# 203                Inhambupe     BA
# 204                   Inhapi     AL
# 205                   Inhuma     PI
# 206                Ipanguaçu     RN
# 207               Ipaporanga     CE
# 208                Ipaumirim     CE
# 209                 Ipecaetá     BA
# 210                    Ipiaú     BA
# 211        Ipiranga do Piauí     PI
# 212                    Ipirá     BA
# 213                  Ipojuca     PE
# 214                      Ipu     CE
# 215                    Ipubi     PE
# 216                  Ipueira     RN
# 217                 Ipueiras     CE
# 218                 Ipupiara     BA
# 219                  Iracema     CE
# 220                  Irajuba     BA
# 221                  Iramaia     BA
# 222                 Iraquara     BA
# 223                    Irará     BA
# 224                 Irauçuba     CE
# 225                    Irecê     BA
# 226            Isaías Coelho     PI
# 227                Itabaiana     PB
# 228                Itabaiana     SE
# 229             Itabaianinha     SE
# 230                  Itabela     BA
# 231                Itaberaba     BA
# 232                    Itabi     SE
# 233                  Itabuna     BA
# 234                  Itacaré     BA
# 235                Itacuruba     PE
# 236                   Itaeté     BA
# 237                    Itagi     BA
# 238                  Itagibá     BA
# 239               Itagimirim     BA
# 240        Itaguaçu da Bahia     BA
# 241              Itainópolis     PI
# 242       Itaipava do Grajaú     MA
# 243                Itaitinga     CE
# 244                 Itaiçaba     CE
# 245         Itaju do Colônia     BA
# 246                 Itajuípe     BA
# 247                    Itajá     RN
# 248                Itamaraju     BA
# 249                  Itamari     BA
# 250                   Itambé     PE
# 251                   Itambé     BA
# 252                 Itanagra     BA
# 253                  Itanhém     BA
# 254                  Itapajé     CE
# 255                Itaparica     BA
# 256                  Itapebi     BA
# 257          Itapecuru Mirim     MA
# 258                 Itapetim     PE
# 259               Itapetinga     BA
# 260                Itapicuru     BA
# 261                Itapipoca     CE
# 262               Itapissuma     PE
# 263               Itapitanga     BA
# 264                 Itapiúna     CE
# 265               Itaporanga     PB
# 266       Itaporanga d'Ajuda     SE
# 267              Itapororoca     PB
# 268                    Itapé     BA
# 269                 Itaquara     BA
# 270              Itaquitinga     PE
# 271                Itarantim     BA
# 272                  Itarema     CE
# 273                   Itatim     BA
# 274                  Itatira     CE
# 275                  Itatuba     PB
# 276                 Itaueira     PI
# 277                   Itaíba     PE
# 278                     Itaú     RN
# 279       Itinga do Maranhão     MA
# 280                  Itiruçu     BA
# 281                   Itiúba     BA
# 282                  Itororó     BA
# 283                   Ituaçu     BA
# 284                  Ituberá     BA
# 285                     Iuiu     BA
# 286                    Ocara     CE
# 287                   Oeiras     PI
# 288     Olho D'Água do Piauí     PI
# 289              Olho d'Água     PB
# 290       Olho d'Água Grande     AL
# 291   Olho d'Água das Cunhãs     MA
# 292   Olho d'Água das Flores     AL
# 293    Olho d'Água do Borges     RN
# 294    Olho d'Água do Casado     AL
# 295                   Olinda     PE
# 296  Olinda Nova do Maranhão     MA
# 297                 Olindina     BA
# 298                 Olivedos     PB
# 299   Oliveira dos Brejinhos     BA
# 300                 Olivença     AL
# 301                    Orobó     PE
# 302                    Orocó     PE
# 303                     Orós     CE
# 304                 Ouricuri     PE
# 305               Ouriçangas     BA
# 306              Ouro Branco     RN
# 307              Ouro Branco     AL
# 308               Ouro Velho     PB
# 309               Ourolândia     BA
# 310                     Uauá     BA
# 311                 Ubaitaba     BA
# 312                  Ubajara     CE
# 313                    Ubatã     BA
# 314                   Ubaíra     BA
# 315                    Uibaí     BA
# 316                  Uiraúna     PB
# 317                    Umari     CE
# 318                 Umarizal     RN
# 319                  Umbaúba     SE
# 320                Umburanas     BA
# 321                Umbuzeiro     PB
# 322                   Umirim     CE
# 323                      Una     BA
# 324                    União     PI
# 325       União dos Palmares     AL
# 326                  Upanema     RN
# 327                   Urandi     BA
# 328            Urbano Santos     MA
# 329              Uruburetama     CE
# 330                   Uruoca     CE
# 331                  Uruçuca     BA
# 332                   Uruçuí     PI
# 333                   Utinga     BA

# %%
municipios_por_estado = df_municipios['Estado'].value_counts()

plt.figure(figsize=(10, 6))
municipios_por_estado.plot(kind='bar', color='purple')
plt.title('Número de Municípios que Começam com Vogais por Estado')
plt.xlabel('Estado')
plt.ylabel('Número de Municípios')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
print(municipios_por_estado)
# Out:
# Estado
# BA    108
# CE     49
# PE     34
# PB     32
# MA     30
# PI     29
# RN     24
# AL     14
# SE     13
# Name: count, dtype: int64
